# %%
import pandas as pd 
import seaborn as sns

# %%
data = pd.read_json('data2.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_54182/3543697351.py in <module>
# ----> 1 data = pd.read_json('data.json')
#
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
sns.countplot(data.label)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>
